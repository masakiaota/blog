# %% [markdown]
# ### 特徴量重要度の可視化

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}
import seaborn as sns
sns.set()

from sklearn.datasets import load_iris
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier(random_state=42)  # limit depth of tree
iris = load_iris()
clf.fit(iris.data, iris.target)
# Out:
# this is modificated versionです
# in this split, we considered [34 22 42 21]
# in this split, we considered [61 37 75 36]
# in this split, we considered [82 50 95 43]
# in this split, we considered [102  63 111  50]
# in this split, we considered [106  67 114  53]
# in this split, we considered [108  68 116  54]
# in this split, we considered [127  79 134  61]
# in this split, we considered [129  81 134  61]
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=42, splitter='best')

# %%
clf.feature_importances_
# Out:
# array([0.01333333, 0.        , 0.56405596, 0.42261071])

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
importance=pd.Series(data=clf.feature_importances_, index=iris.feature_names)
importance=importance.sort_values()

# %%
importance.plot.barh()

# %% [markdown]
# ### 組み込んだのでやってみる

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
import numpy as np
import pandas as pd

# import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %matplotlib inline
import seaborn as sns
sns.set()

from sklearn.datasets import load_iris
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier(random_state=42)  # limit depth of tree
iris = load_iris()
clf.fit(iris.data, iris.target)
# Out:
# this is modificated versionです
# in this split, we considered [34 22 42 21]
# in this split, we considered [61 37 75 36]
# in this split, we considered [82 50 95 43]
# in this split, we considered [102  63 111  50]
# in this split, we considered [106  67 114  53]
# in this split, we considered [108  68 116  54]
# in this split, we considered [127  79 134  61]
# in this split, we considered [129  81 134  61]
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=42, splitter='best')

# %%
clf.show_importances(iris.feature_names)
