# %% [markdown]
# ### データの取得
# UCIリポジトリからair qualityのダウンロード

# %%
import os
import urllib.request
from zipfile import ZipFile

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
#データのダウンロード
URL="https://archive.ics.uci.edu/ml/machine-learning-databases/00360/AirQualityUCI.zip"
data_dir = "./data/"
file=os.path.join(data_dir,"AirQualityUCI.zip")
urllib.request.urlretrieve(URL, file)
with ZipFile(file) as z:
    z.extract("AirQualityUCI.csv", data_dir)
os.remove(file)

# %% [markdown]
# このcsvは小数点が,で分割が;

# %%
data = pd.read_csv(os.path.join(data_dir,"AirQualityUCI.csv"),
                  sep =";", decimal=",")
data.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# ...

# %% [markdown]
# ### データについて
#
# - 時間の解像度: 1時間ごと
# - 様々なものの濃度： 二酸化炭素濃度, 酸化スズ, 非炭化水素, ベンゼン, 窒素等の情報
# - 気温、相対湿度、絶対湿度の情報

# %% [markdown]
# ### データの整理

# %% [markdown]
# 多変量なのがめんどくさくなってきた
# 他の電力需要でやる
